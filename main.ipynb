# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo: Excel → Word
# - Esse fluxo é responsável por transformar os casos de teste presentes na planilha excel para um documento estruturado em Word

# %% [markdown]
# > Para o fluxo funcionar é preciso rodar as instalações abaixo

# %%
# Instalações de bibliotecas necessárias para o fluxo.
# %pip install pandas
# %pip install python-docx openpyxl

# %%
# Fluxo
from fluxos.excel_word import excel_word

# Coloque o caminho que gostaria de salvar os documentos Words.
# Exemplo: "C:/Users/Usuario/Desktop/Documentos_Word/"
caminho = r"C:\Users\bruno\OneDrive\Documentos\Documentos_words"

# Selecione a plhanila que deseja gerar os documentos Words.
planilha = 'Planejamento'

# Preencha os dados para tabela do documento Word.
dados = {
    "URL": "teste.com",
    "Browser/Versão": "Edge",
    "Realizado em": "01/03/2026",
    "Status do Teste": "",
}

fluxo = excel_word()
fluxo.selec_planilha()
fluxo.criar_doc(dados, caminho, planilha)

# %% [markdown]
# ### Sub Fluxo: Adição de imagens nos steps repetidos
# - Esse fluxo é responsável por adicionar as imagens em steps que se repetem em vários documentos

# %%
# Fluxo

# %% [markdown]
# ## Fluxo: Service now → Word
# - Esse fluxo é responsável por transformar os casos de teste presentes no service now para um documento estruturado em Word

# %% [markdown]
# ## Fluxo: Sharepoint
# - Esse fluxo é responsável por:
#
# 		Transformar word em PDF → Zipar em uma pasta com nomenclatura padrão → Colocar a pasta zipada e a planilha excel no Sharepoint em seu respectivo projeto e mês
