# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo: Excel → Word
# - Esse fluxo é responsável por transformar os casos de teste presentes na planilha excel para um documento estruturado em Word

# %%
from fluxo_ew import FluxoEW

dados = {
    "URL": "teste.com",
    "Browser/Versão": "Edge",
    "Realizado em": "01/03/2026",
    "Status do Teste": "",
}

fluxo = FluxoEW()
fluxo.selec_planilha()
fluxo.criar_documento(dados)
# Out:
# Arquivo Excel selecionado: C:/Users/bruno/OneDrive/Documentos/Modelos/Planilha de Medicao NORTEC - Fevereiro_2026.xlsx
# Documento gerado: Card STS0149727 - TC 199_Modal norma_Upload e Acesso a Documentos de Apoio no modal Norma.docx
# Documento gerado: Card STS0149727 - TC 200_Modal norma_Acesso ao sharepoint sem acesso.docx
# Documento gerado: Card STS0149727 - TC 201_Modal norma_Upload do tipo DOC.docx
# Documento gerado: Card STS0149727 - TC 202_Modal norma_Upload do tipo XLSM.docx
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 12
#      10 fluxo = FluxoEW()
#      11 fluxo.selec_planilha()
# ---> 12 fluxo.criar_documento(dados)
#
# File c:\Users\bruno\OneDrive\Documentos\ProjetoBMSL-Automacao-Migracao_de_dados\fluxo_ew.py:90, in FluxoEW.criar_documento(self, dados)
#      87 nome_arquivo = f"{row['Import Test Case Name']}.docx"
#      88 caminho = os.path.join(output_folder, nome_arquivo)
# ---> 90 doc.save(caminho)
#      91 print(f"Documento gerado: {nome_arquivo}")
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\site-packages\docx\document.py:204, in Document.save(self, path_or_stream)
#     198 def save(self, path_or_stream: str | IO[bytes]):
#     199     """Save this document to `path_or_stream`.
#     200
#     201     `path_or_stream` can be either a path to a filesystem location (a string) or a
#     202     file-like object.
#     203     """
# --> 204     self._part.save(path_or_stream)
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\site-packages\docx\parts\document.py:114, in DocumentPart.save(self, path_or_stream)
#     111 def save(self, path_or_stream: str | IO[bytes]):
#     112     """Save this document to `path_or_stream`, which can be either a path to a
#     113     filesystem location (a string) or a file-like object."""
# --> 114     self.package.save(path_or_stream)
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\site-packages\docx\opc\package.py:166, in OpcPackage.save(self, pkg_file)
#     164 for part in self.parts:
#     165     part.before_marshal()
# --> 166 PackageWriter.write(pkg_file, self.rels, self.parts)
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\site-packages\docx\opc\pkgwriter.py:34, in PackageWriter.write(pkg_file, pkg_rels, parts)
#      30 @staticmethod
#      31 def write(pkg_file, pkg_rels, parts):
#      32     """Write a physical package (.pptx file) to `pkg_file` containing `pkg_rels` and
#      33     `parts` and a content types stream based on the content types of the parts."""
# ---> 34     phys_writer = PhysPkgWriter(pkg_file)
#      35     PackageWriter._write_content_types_stream(phys_writer, parts)
#      36     PackageWriter._write_pkg_rels(phys_writer, pkg_rels)
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\site-packages\docx\opc\phys_pkg.py:109, in _ZipPkgWriter.__init__(self, pkg_file)
#     107 def __init__(self, pkg_file):
#     108     super(_ZipPkgWriter, self).__init__()
# --> 109     self._zipf = ZipFile(pkg_file, "w", compression=ZIP_DEFLATED)
#
# File c:\Users\bruno\AppData\Local\Programs\Python\Python314\Lib\zipfile\__init__.py:1453, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1451 while True:
#    1452     try:
# -> 1453         self.fp = io.open(file, filemode)
#    1454     except OSError:
#    1455         if filemode in modeDict:
#
# OSError: [Errno 22] Invalid argument: 'docs_gerados\\Card STS0149727 - TC 203_Modal "Documentos de apoio"_Upload e Acesso a Documentos de Apoio\xa0no modal Documentos de apoio.docx'

# %% [markdown]
# ## Fluxo: Service now → Word
# - Esse fluxo é responsável por transformar os casos de teste presentes no service now para um documento estruturado em Word

# %% [markdown]
# ## Fluxo: Sharepoint
# - Esse fluxo é responsável por:
#
# 		Transformar word em PDF → Zipar em uma pasta com nomenclatura padrão → Colocar a pasta zipada e a planilha excel no Sharepoint em seu respectivo projeto e mês
